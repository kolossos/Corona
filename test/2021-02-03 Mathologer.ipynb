# %% [markdown]
# ### Mathologer: Times Tables, Mandelbrot and the Heart of Mathematics
#
# https://www.youtube.com/watch?v=qhbuKbxJsk8
#
# https://de.wikipedia.org/wiki/Kardioide#Kardioide_als_Einhüllende_einer_Geradenschar

# %%
# %matplotlib inline
#from numpy import arange, cos, linspace, pi, sin, random
import numpy as np
import matplotlib.pyplot as plt

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

plt.rcParams['figure.figsize']=(7,7)
# %config InlineBackend.figure_format="jpg"

# %%
n=200
points=np.arange(n)

# %%
x=np.cos(2*np.pi*points/n)
y=np.sin(2*np.pi*points/n)
p=np.array([x,y]).T

# %%
i=34
plt.plot(x,y);
for j in np.arange(n):
    plt.plot([p[j,0],p[int(i*j)%n,0]],[p[j,1],p[int(i*j)%n,1]]);

# %%
def f(i):
    xxx=[p[0,0],p[int(i*0)%n,0]]
    yyy=[p[0,1],p[int(i*0)%n,1]]

    for j in np.arange(n)[1:]:
        xxx= np.vstack([xxx,[p[j,0],p[int(i*j)%n,0]]])
        yyy= np.vstack([yyy,[p[j,1],p[int(i*j)%n,1]]])

    plt.plot(xxx.T,yyy.T, '-');

# %%
interact(f, i=(0,100.101));
# Out:
# interactive(children=(FloatSlider(value=50.0505, description='i', max=100.101), Output()), _dom_classes=('widg…

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
plott = figure(title="simple line example", plot_height=500, plot_width=500, y_range=(-1,1),
           background_fill_color='#efefef')
r=[]
for j in np.arange(n):
    r=np.append(r,plott.line([p[j,0],p[int(i*j)%n,0]],[p[j,1],p[int(i*j)%n,1]], line_width=1))

#r = [plott.line(x, y, color="#8888cc", line_width=1.5, alpha=0.8),plott.line(x, y2, color="#8888cc", line_width=1.5, alpha=0.8)]

# %%
def update(i):
    plott.title.text=str(i)
    xx=[]
    yy=[]
    for j in np.arange(n):
        xx=[p[j,0],p[int(i*j)%n,0]]
        yy=[p[j,1],p[int(i*j)%n,1]]
        r[j].data_source.data['x'] = xx
        r[j].data_source.data['y'] = yy
        #r=np.append(r,plott.line([p[j,0],p[int(i*j)%n,0]],[p[j,1],p[int(i*j)%n,1]], line_width=3))  
    push_notebook()

# %%
show(plott, notebook_handle=True);
# Out:
#   <div class="bk-root" id="966aa2cc-ddc5-49c0-b74a-857851182434" data-root-id="1002"></div>

# %%
interact(update, i=(1,100.0,.01));
# Out:
# interactive(children=(FloatSlider(value=50.5, description='i', min=1.0, step=0.01), Output()), _dom_classes=('…
